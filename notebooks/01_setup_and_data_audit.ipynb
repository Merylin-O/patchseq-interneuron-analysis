# %% [markdown]
# <a href="https://colab.research.google.com/github/Merylin-O/patchseq-interneuron-analysis/blob/main/notebooks/01_setup_and_data_audit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Patch-seq Interneuron Analysis
#
# ## Notebook 01: Setup and Data Audit
#
# This notebook sets up the project environment and will be used to inspect the Patch-seq dataset before analysis.
#
# ### Initial research question
#
# How do Pvalb, Sst, Vip and Lamp5 interneurons differ in their intrinsic electrophysiological properties, and how are selected ion-channel genes associated with these differences?

# %%
# Check the python version
import sys
import platform

print("Python version is", sys.version)
print("Operating system is", platform.platform())
# Out:
# Python version is 3.13.15 (main, Aug  6 2026, 11:06:22) [GCC 13.3.0]
# Operating system is Linux-6.6.122+-x86_64-with-glibc2.39

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import sklearn

# %%
# connect google drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# to create the storage folders
from pathlib import Path
project_dir = Path("/content/drive/MyDrive/patchseq_project")

folders = [
    project_dir/"data"/"raw",
    project_dir/"data"/"processed",
    project_dir/"results"/"tables",
    project_dir/"results"/"figures"
]

for folder in folders:
  folder.mkdir(parents=True, exist_ok=True)

print("Project folder:", project_dir)

for folder in folders:
  print("Created", folder)
# Out:
# Project folder: /content/drive/MyDrive/patchseq_project
# Created /content/drive/MyDrive/patchseq_project/data/raw
# Created /content/drive/MyDrive/patchseq_project/data/processed
# Created /content/drive/MyDrive/patchseq_project/results/tables
# Created /content/drive/MyDrive/patchseq_project/results/figures
